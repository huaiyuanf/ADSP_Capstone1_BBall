# %%
import os
import glob
from IPython.display import Image,display

# %%
# !nvidia-smi
# Out:
# Wed Apr 24 13:06:36 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.23                 Driver Version: 551.23         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080      WDDM  |   00000000:0B:00.0  On |                  N/A |
# |  0%   53C    P8             48W /  380W |    1586MiB /  10240MiB |     37%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # set up home repo

# %%
HOME = os.getcwd()

# %%
HOME
# Out:
# 'C:\\Users\\herry\\Desktop\\capstone1'

# %% [markdown]
# # Set up yolo

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2  Python-3.11.4 torch-2.2.2+cpu CPU (AMD Ryzen 9 5900X 12-Core Processor)
# Setup complete  (24 CPUs, 31.9 GB RAM, 512.1/930.7 GB disk)

# %%
from ultralytics import YOLO

# %% [markdown]
# # Set up roboflow

# %%
# %cd {HOME}/dataset
# Out:
# C:\Users\herry\Desktop\capstone1\dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1cAgflwN1A3Nqe5Tl9EQ")
project = rf.workspace("watermark-dqqep").project("thumbsup-twb7i")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.2, to fix: `pip install ultralytics==8.0.196`

# %% [markdown]
# # Train model

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=10 imgsz=200
# Out:
# C:\Users\herry\Desktop\capstone1
# ...
# Ultralytics YOLOv8.2.2 馃殌 Python-3.11.4 torch-2.2.2+cpu CPU (AMD Ryzen 9 5900X 12-Core Processor)
# ...

# %% [markdown]
# # Validate

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train17/weights/best.pt data={dataset.location}/data.yaml
# Out:
# C:\Users\herry\Desktop\capstone1
# Ultralytics YOLOv8.2.2 馃殌 Python-3.11.4 torch-2.2.2+cpu CPU (AMD Ryzen 9 5900X 12-Core Processor)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
#                    all         47         47      0.997          1      0.995      0.891
# Speed: 0.1ms preprocess, 51.5ms inference, 0.0ms loss, 23.4ms postprocess per image
# Results saved to runs\detect\val
# 馃挕 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\herry\Desktop\capstone1\dataset\Thumbsup-1\valid\labels.cache... 47 images, 0 backgrounds, 0 corrupt: 100%|██████████| 47/47 [00:00<?, ?it/s]
# val: Scanning C:\Users\herry\Desktop\capstone1\dataset\Thumbsup-1\valid\labels.cache... 47 images, 0 backgrounds, 0 corrupt: 100%|██████████| 47/47 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# ...
